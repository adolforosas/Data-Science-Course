# %% [markdown]
# # My Jupyter Notebook

# %% [markdown]
# __Adolfo Rosas__<br>
# Sales Executive

# %% [markdown]
# _I am interested in data science because i want to change my carrer from sales to data scientist_

# %% [markdown]
# ### My code in cell 5 display my name

# %%
print("Adolfo Rosas")
# Out:
# Adolfo Rosas

# %% [markdown]
# - bulleted item 1
# - bulleted item 2
# <hr>
# 1 numbered item 1 <br>
# 2 numbered item 2
# <hr>
# <img src="https://www.bing.com/th?id=OIP.Quq7YO6nNVwYZay4NoeocgHaHa&w=150&h=150&c=8&rs=1&qlt=90&o=6&dpr=1.5&pid=3.1&rm=2" alt= "logo"  />
